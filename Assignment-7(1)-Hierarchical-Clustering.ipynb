# %%
import pandas as pd    # Importing Libraries
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import normalize

# %%
Airline = pd.read_excel("EastWestAirlines.xlsx",sheet_name = 1)
Airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airline_1 = Airline.drop(['ID#'],axis=1)
Airline_1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
Airline_1_norm = pd.DataFrame(normalize(Airline_1), columns = Airline_1.columns)
Airline_1_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
plt.figure(figsize=(8, 5))    # Create Dendrograms
Dendograms=sch.dendrogram(sch.linkage(Airline_1_norm,'complete'))

# %%
hclusters=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='complete') # Create Clusters (y)
hclusters
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=5)

# %%
y=pd.DataFrame(hclusters.fit_predict(Airline_1_norm),columns=['clustersid'])
y['clustersid'].value_counts()
# Out:
# 0    3086
# 1     509
# 3     197
# 2     137
# 4      70
# Name: clustersid, dtype: int64

# %%
Airline_1['clustersid']=hclusters.labels_  # Adding clusters to dataset
Airline_1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline_1.groupby('clustersid').agg(['mean']).reset_index()
# Out:
#   clustersid       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                       mean        mean      mean      mean      mean
# 0          0  85958.186325  163.835386  1.876215  1.012638  1.002916
# 1          1  49938.428291  109.797642  3.418468  1.031434  1.049116
# 2          2  15395.744526   93.620438  3.189781  1.021898  1.109489
# 3          3   7222.208122   10.177665  1.005076  1.000000  1.000000
# 4          4   1629.914286    0.000000  1.014286  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  13503.547959   11.000648        469.272197        1.402787
# 1  40242.673870   18.194499        584.611002        1.722986
# 2  44896.007299   17.065693        560.094891        1.708029
# 3   1067.822335    3.395939         72.786802        0.213198
# 4    652.228571    2.571429         42.142857        0.157143
#
#   Days_since_enroll    Award?
# ...

# %%
plt.figure(figsize=(10, 7))  # Plot Clusters
plt.scatter(Airline_1['clustersid'],Airline_1['Balance'], c=hclusters.labels_)
